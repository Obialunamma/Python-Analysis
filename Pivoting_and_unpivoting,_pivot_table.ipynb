# %% [markdown]
# <a href="https://colab.research.google.com/github/Obialunamma/Python-Analysis/blob/main/Pivoting_and_unpivoting%2C_pivot_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
s = pd.read_csv("/content/sales_wide.csv")
s
# Out:
#    Region Product  Year  January  February  March  April  May  June  July  \
# 0    East   Apple  2024      152       409     71    104  314    99   495
# 1    East  Orange  2024      485       201    302    293  395   409   319
# 2    East  Banana  2024      398       180    285    369  102   437   400
# 3    East   Grape  2024      320       199    394    180  435    51   353
# 4    East   Mango  2024      156       358     98    356  389   439   320
# 5    West   Apple  2024      121       307    108    184  141   103   264
# 6    West  Orange  2024      238       393    219     70  416   155   301
# 7    West  Banana  2024       70       463    237    378  493   309   239
# 8    West   Grape  2024      152       343    320    216  477   359   345
# 9    West   Mango  2024      171       435    239    323  313   240   262
# 10  North   Apple  2024      264       241    495    437  480   451   257
# 11  North  Orange  2024      380       493    224    138   84   267   286
# ...

# %%
s.columns
# Out:
# Index(['Region', 'Product', 'Year', 'January', 'February', 'March', 'April',
#        'May', 'June', 'July', 'August', 'September', 'October', 'November',
#        'December', 'TargetAnnual'],
#       dtype='object')

# %%
s.isna().sum()
# Out:
# Region          0
# Product         0
# Year            0
# January         0
# February        0
# March           0
# April           0
# May             0
# June            0
# July            0
# August          0
# September       0
# October         0
# November        0
# December        0
# TargetAnnual    0
# dtype: int64

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Region        15 non-null     object
#  1   Product       15 non-null     object
#  2   Year          15 non-null     int64
#  3   Jan           15 non-null     int64
#  4   Feb           15 non-null     int64
#  5   Mar           15 non-null     int64
#  6   Apr           15 non-null     int64
#  7   May           15 non-null     int64
#  8   Jun           15 non-null     int64
#  9   Jul           15 non-null     int64
#  10  Aug           15 non-null     int64
#  11  Sep           15 non-null     int64
#  12  Oct           15 non-null     int64
#  13  Nov           15 non-null     int64
#  14  Dec           15 non-null     int64
#  15  TargetAnnual  15 non-null     int64
# dtypes: int64(14), object(2)
# memory usage: 2.0+ KB

# %%
s.duplicated().sum()
# Out:
# np.int64(0)

# %%
m = s.melt(id_vars=["Region", "Product", "Year", "TargetAnnual"],
# value_vars=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],
var_name="Month",
value_name="Sales")


print(m)
# Out:
#     Region Product  Year  TargetAnnual     Month  Sales
# 0     East   Apple  2024          4678   January    152
# 1     East  Orange  2024          3540   January    485
# 2     East  Banana  2024          4059   January    398
# 3     East   Grape  2024          5572   January    320
# 4     East   Mango  2024          4183   January    156
# ..     ...     ...   ...           ...       ...    ...
# 175  North   Apple  2024          4597  December    437
# 176  North  Orange  2024          5693  December    271
# 177  North  Banana  2024          3795  December    456
# 178  North   Grape  2024          4051  December    280
# 179  North   Mango  2024          4643  December    286
#
# [180 rows x 6 columns]

# %%
m
# Out:
#     Region Product  Year  TargetAnnual Month  Sales
# 0     East   Apple  2024          4678   Jan    152
# 1     East  Orange  2024          3540   Jan    485
# 2     East  Banana  2024          4059   Jan    398
# 3     East   Grape  2024          5572   Jan    320
# 4     East   Mango  2024          4183   Jan    156
# ..     ...     ...   ...           ...   ...    ...
# 175  North   Apple  2024          4597   Dec    437
# 176  North  Orange  2024          5693   Dec    271
# 177  North  Banana  2024          3795   Dec    456
# 178  North   Grape  2024          4051   Dec    280
# 179  North   Mango  2024          4643   Dec    286
#
# [180 rows x 6 columns]

# %%
print(m.to_string())
# Out:
#     Region Product  Year  TargetAnnual Month  Sales
# 0     East   Apple  2024          4678   Jan    152
# 1     East  Orange  2024          3540   Jan    485
# 2     East  Banana  2024          4059   Jan    398
# 3     East   Grape  2024          5572   Jan    320
# 4     East   Mango  2024          4183   Jan    156
# 5     West   Apple  2024          4722   Jan    121
# 6     West  Orange  2024          4819   Jan    238
# 7     West  Banana  2024          5625   Jan     70
# 8     West   Grape  2024          5729   Jan    152
# 9     West   Mango  2024          5604   Jan    171
# 10   North   Apple  2024          4597   Jan    264
# 11   North  Orange  2024          5693   Jan    380
# 12   North  Banana  2024          3795   Jan    137
# 13   North   Grape  2024          4051   Jan    422
# 14   North   Mango  2024          4643   Jan    149
# 15    East   Apple  2024          4678   Feb    409
# 16    East  Orange  2024          3540   Feb    201
# ...

# %%
p = pd.read_csv("/content/PQ Exercise 1d.csv")
p
# Out:
#     Metric  Store  Cat  01/01/2017  02/01/2017  03/01/2017      Q1 2017  \
# 0    Sales      1    1         NaN         NaN         NaN          NaN
# 1      NaN      1    2  50605.2700  44682.7400  47928.8900  143216.9000
# 2      NaN      1    3  13740.1200  10887.8400  11523.4700   36151.4300
# 3      NaN      1    4  39954.0400  35351.2100  36826.9500  112132.2000
# 4      NaN      2    1  35034.0600  60483.7000  58221.5200  153739.2800
# 5      NaN      2    2  74661.1600  65487.4600  70853.5800  211002.2000
# 6      NaN      2    3  16873.2000  13821.0100  14607.2800   45301.4900
# 7      NaN      2    4  47681.9600  44197.9500  46131.1400  138011.0500
# 8   Margin      1    1         NaN         NaN         NaN          NaN
# 9      NaN      1    2      0.5542      0.5542      0.5542       0.5542
# 10     NaN      1    3      0.5212      0.5212      0.5212       0.5212
# 11     NaN      1    4      0.5462      0.5462      0.5462       0.5462
# ...

# %%
p = p.melt(id_vars=["Metric",	"Store",	"Cat"],
    var_name="Date",
    value_name="Sales")

print(p)
# Out:
#     Metric  Store  Cat        Date       Sales
# 0    Sales      1    1  01/01/2017         NaN
# 1      NaN      1    2  01/01/2017  50605.2700
# 2      NaN      1    3  01/01/2017  13740.1200
# 3      NaN      1    4  01/01/2017  39954.0400
# 4      NaN      2    1  01/01/2017  35034.0600
# ..     ...    ...  ...         ...         ...
# 539    NaN      1    4        2018      0.5462
# 540    NaN      2    1        2018      0.5432
# 541    NaN      2    2        2018      0.5542
# 542    NaN      2    3        2018      0.5212
# 543    NaN      2    4        2018      0.5462
#
# [544 rows x 5 columns]

# %%
# Fill down the Metric column
p['Metric'] = p['Metric'].ffill()

# %%
print(p.to_string())

# %%
p.head()
# Out:
#   Metric  Store  Cat        Date     Sales
# 0  Sales      1    1  01/01/2017       NaN
# 1  Sales      1    2  01/01/2017  50605.27
# 2  Sales      1    3  01/01/2017  13740.12
# 3  Sales      1    4  01/01/2017  39954.04
# 4  Sales      2    1  01/01/2017  35034.06

# %%
v = p.pivot(index=['Store', 'Cat', 'Date'], columns='Metric', values='Sales')
v
# Out:
# Metric                Margin      Sales
# Store Cat Date
# 1     1   01/01/2017     NaN        NaN
#           01/01/2018  0.5432   24924.50
#           02/01/2017     NaN        NaN
#           02/01/2018  0.5432   46039.49
#           03/01/2017     NaN        NaN
# ...                      ...        ...
# 2     4   Q2 2018     0.5462  131553.73
#           Q3 2017     0.5462  134029.66
#           Q3 2018     0.5462  134029.66
#           Q4 2017     0.5462  132448.20
#           Q4 2018     0.5462  132448.20
#
# [272 rows x 2 columns]

# %%
v.columns.name =None

# %%
v.reset_index(inplace=True)

# %%
v
# Out:
#      Store  Cat        Date  Margin      Sales
# 0        1    1  01/01/2017     NaN        NaN
# 1        1    1  01/01/2018  0.5432   24924.50
# 2        1    1  02/01/2017     NaN        NaN
# 3        1    1  02/01/2018  0.5432   46039.49
# 4        1    1  03/01/2017     NaN        NaN
# ..     ...  ...         ...     ...        ...
# 267      2    4     Q2 2018  0.5462  131553.73
# 268      2    4     Q3 2017  0.5462  134029.66
# 269      2    4     Q3 2018  0.5462  134029.66
# 270      2    4     Q4 2017  0.5462  132448.20
# 271      2    4     Q4 2018  0.5462  132448.20
#
# [272 rows x 5 columns]

# %% [markdown]
# error =
#
# raise → complain and stop.
#
# ignore → leave bad values untouched.
#
# coerce → force conversion, replace bad ones with NaT/NaN.

# %%
pd.to_datetime(v['Date'], errors='coerce', format='mixed')
# Out:
# 0     2017-01-01
# 1     2018-01-01
# 2     2017-02-01
# 3     2018-02-01
# 4     2017-03-01
#          ...
# 267          NaT
# 268          NaT
# 269          NaT
# 270          NaT
# 271          NaT
# Name: Date, Length: 272, dtype: datetime64[ns]

# %%
# errors="coerce" = "try to convert; if it fails, don’t crash, just put NaT".
v['Date'] = pd.to_datetime(v['Date'], errors='coerce', format='mixed')

# %%
v.head()
# Out:
#    Store  Cat       Date  Margin     Sales
# 0      1    1 2017-01-01     NaN       NaN
# 1      1    1 2018-01-01  0.5432  24924.50
# 2      1    1 2017-02-01     NaN       NaN
# 3      1    1 2018-02-01  0.5432  46039.49
# 4      1    1 2017-03-01     NaN       NaN

# %%
v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   272 non-null    int64
#  1   Cat     272 non-null    int64
#  2   Date    208 non-null    datetime64[ns]
#  3   Margin  268 non-null    float64
#  4   Sales   268 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 10.8 KB

# %%
v.dropna(inplace = True)

# %%
v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, 1 to 263
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   205 non-null    int64
#  1   Cat     205 non-null    int64
#  2   Date    205 non-null    datetime64[ns]
#  3   Margin  205 non-null    float64
#  4   Sales   205 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 9.6 KB

# %%
v.isna().any()
# Out:
# Store     False
# Cat       False
# Date      False
# Margin    False
# Sales     False
# dtype: bool

# %%
v.reset_index(drop=True)
# Out:
#      Store  Cat       Date  Margin      Sales
# 0        1    1 2018-01-01  0.5432   24924.50
# 1        1    1 2018-02-01  0.5432   46039.49
# 2        1    1 2018-03-01  0.5432   41595.55
# 3        1    1 2017-04-01  0.5432   19403.54
# 4        1    1 2018-04-01  0.5432   19403.54
# ..     ...  ...        ...     ...        ...
# 200      2    4 2018-11-01  0.5462   43463.55
# 201      2    4 2017-12-01  0.5462   43703.76
# 202      2    4 2018-12-01  0.5462   43703.76
# 203      2    4 2017-01-01  0.5462  536042.64
# 204      2    4 2018-01-01  0.5462  536042.64
#
# [205 rows x 5 columns]

# %%
v["Profit"] = round((v["Margin"] * v["Sales"]),2)
v["Profit"]
# Out:
# 1       13538.99
# 3       25008.65
# 5       22594.70
# 6       10540.00
# 7       10540.00
#          ...
# 259     23739.79
# 260     23870.99
# 261     23870.99
# 262    292786.49
# 263    292786.49
# Name: Profit, Length: 205, dtype: float64

# %%
(v.Margin * v.Sales).round(2)
# Out:
# 1       13538.99
# 3       25008.65
# 5       22594.70
# 6       10540.00
# 7       10540.00
#          ...
# 259     23739.79
# 260     23870.99
# 261     23870.99
# 262    292786.49
# 263    292786.49
# Length: 205, dtype: float64

# %%
v.rename(columns= {'Cat': 'Category'}, inplace = True)

# %%
v['Month'] = v['Date'].dt.month_name()

# %%
v
# Out:
#      Store  Category       Date  Margin      Sales     Profit     Month
# 1        1         1 2018-01-01  0.5432   24924.50   13538.99   January
# 3        1         1 2018-02-01  0.5432   46039.49   25008.65  February
# 5        1         1 2018-03-01  0.5432   41595.55   22594.70     March
# 6        1         1 2017-04-01  0.5432   19403.54   10540.00     April
# 7        1         1 2018-04-01  0.5432   19403.54   10540.00     April
# ..     ...       ...        ...     ...        ...        ...       ...
# 259      2         4 2018-11-01  0.5462   43463.55   23739.79  November
# 260      2         4 2017-12-01  0.5462   43703.76   23870.99  December
# 261      2         4 2018-12-01  0.5462   43703.76   23870.99  December
# 262      2         4 2017-01-01  0.5462  536042.64  292786.49   January
# 263      2         4 2018-01-01  0.5462  536042.64  292786.49   January
#
# [205 rows x 7 columns]

# %%
m.drop(columns=['Year'])
m.drop('Year', axis = 1)
# Out:
#     Region Product  TargetAnnual     Month  Sales
# 0     East   Apple          4678   January    152
# 1     East  Orange          3540   January    485
# 2     East  Banana          4059   January    398
# 3     East   Grape          5572   January    320
# 4     East   Mango          4183   January    156
# ..     ...     ...           ...       ...    ...
# 175  North   Apple          4597  December    437
# 176  North  Orange          5693  December    271
# 177  North  Banana          3795  December    456
# 178  North   Grape          4051  December    280
# 179  North   Mango          4643  December    286
#
# [180 rows x 5 columns]

# %%
t = m.groupby(["Region", "Product"]).agg({"Sales": "sum", "TargetAnnual": "first"})
t
# Out:
#                 Sales  TargetAnnual
# Region Product
# East   Apple     3294          4678
#        Banana    3445          4059
#        Grape     3596          5572
#        Mango     2857          4183
#        Orange    3792          3540
# North  Apple     4042          4597
#        Banana    3831          3795
#        Grape     2486          4051
#        Mango     3049          4643
#        Orange    3370          5693
# West   Apple     2902          4722
#        Banana    3531          5625
#        Grape     3284          5729
#        Mango     3695          5604
#        Orange    2884          4819

# %%
T = m.groupby(["Region", "Product"], as_index=False).agg({"Sales": "sum", "TargetAnnual": "mean"})
T
# Out:
#    Region Product  Sales  TargetAnnual
# 0    East   Apple   3294          4678
# 1    East  Banana   3445          4059
# 2    East   Grape   3596          5572
# 3    East   Mango   2857          4183
# 4    East  Orange   3792          3540
# 5   North   Apple   4042          4597
# 6   North  Banana   3831          3795
# 7   North   Grape   2486          4051
# 8   North   Mango   3049          4643
# 9   North  Orange   3370          5693
# 10   West   Apple   2902          4722
# 11   West  Banana   3531          5625
# 12   West   Grape   3284          5729
# 13   West   Mango   3695          5604
# 14   West  Orange   2884          4819

# %%
t["Achieved"] = t["Sales"] >= t["TargetAnnual"]
t["Difference"] = t["Sales"] - t["TargetAnnual"]

print(t)
# Out:
#                 Sales  TargetAnnual  Achieved  Difference
# Region Product
# East   Apple     3294          4678     False       -1384
#        Banana    3445          4059     False        -614
#        Grape     3596          5572     False       -1976
#        Mango     2857          4183     False       -1326
#        Orange    3792          3540      True         252
# North  Apple     4042          4597     False        -555
#        Banana    3831          3795      True          36
#        Grape     2486          4051     False       -1565
#        Mango     3049          4643     False       -1594
#        Orange    3370          5693     False       -2323
# West   Apple     2902          4722     False       -1820
#        Banana    3531          5625     False       -2094
#        Grape     3284          5729     False       -2445
#        Mango     3695          5604     False       -1909
#        Orange    2884          4819     False       -1935

# %%
t.Achieved.value_counts()
# Out:
# Achieved
# False    13
# True      2
# Name: count, dtype: int64

# %%
print(sum(t.TargetAnnual))
print(sum(t.Sales))
print(sum(t.TargetAnnual) - sum(t.Sales))
# Out:
# 71310
# 50058
# 21252

# %%
print(f"{sum(t.TargetAnnual):,}")
print(f"{sum(t.Sales):,}")
print(f"{sum(t.TargetAnnual) - sum(t.Sales):,}")
# Out:
# 71,310
# 50,058
# 21,252

# %%
i = m.pivot_table(index=["Region", "Product"], values=["Sales", "TargetAnnual"],aggfunc={"Sales": "sum", "TargetAnnual": "first"}) #.reset_index()
i
# Out:
#                 Sales  TargetAnnual
# Region Product
# East   Apple     3294          4678
#        Banana    3445          4059
#        Grape     3596          5572
#        Mango     2857          4183
#        Orange    3792          3540
# North  Apple     4042          4597
#        Banana    3831          3795
#        Grape     2486          4051
#        Mango     3049          4643
#        Orange    3370          5693
# West   Apple     2902          4722
#        Banana    3531          5625
#        Grape     3284          5729
#        Mango     3695          5604
#        Orange    2884          4819

# %%
i["Achieved"] = i["Sales"] >= i["TargetAnnual"]
i["Difference"] = i["Sales"] - i["TargetAnnual"]
i
# Out:
#                 Sales  TargetAnnual  Achieved  Difference
# Region Product
# East   Apple     3294          4678     False       -1384
#        Banana    3445          4059     False        -614
#        Grape     3596          5572     False       -1976
#        Mango     2857          4183     False       -1326
#        Orange    3792          3540      True         252
# North  Apple     4042          4597     False        -555
#        Banana    3831          3795      True          36
#        Grape     2486          4051     False       -1565
#        Mango     3049          4643     False       -1594
#        Orange    3370          5693     False       -2323
# West   Apple     2902          4722     False       -1820
#        Banana    3531          5625     False       -2094
#        Grape     3284          5729     False       -2445
#        Mango     3695          5604     False       -1909
#        Orange    2884          4819     False       -1935

# %%
m.pivot_table(index = ['Month'], values=['Sales'], aggfunc='sum').sort_values(by='Sales', ascending=False)
# Out:
#            Sales
# Month
# February    4921
# May         4893
# July        4746
# November    4464
# December    4202
# August      4066
# March       4000
# October     3889
# June        3874
# April       3767
# September   3621
# January     3615

# %%
v.pivot_table(index = ['Month'], values=['Profit'], aggfunc='sum').sort_values(by='Profit', ascending=False)
# Out:
#                Profit
# Month
# January    4086970.39
# September   399693.46
# October     354855.64
# March       335367.14
# February    325486.79
# May         304145.28
# June        282607.76
# August      282202.20
# April       282173.86
# July        280809.58
# November    271494.50
# December    270811.40

# %%
v.groupby("Month")["Profit"].sum().sort_values(ascending=False)
# Out:
# Month
# January      4086970.39
# September     399693.46
# October       354855.64
# March         335367.14
# February      325486.79
# May           304145.28
# June          282607.76
# August        282202.20
# April         282173.86
# July          280809.58
# November      271494.50
# December      270811.40
# Name: Profit, dtype: float64

# %%
v.pivot_table(index = ['Store', 'Month'], values=['Profit'], aggfunc=['sum', 'mean']).round(2)

# %%
v.groupby(['Store', 'Month']).agg({'Profit': ['sum', 'mean'], 'Sales': ['sum']}).round(2)
# Out:
#                      Profit                  Sales
#                         sum       mean         sum
# Store Month
# 1     April       119644.28   14955.54   218983.48
#       August      122737.36   15342.17   224721.36
#       December    112948.78   14118.60   206478.20
#       February    124502.13   17786.02   227883.07
#       January    1725255.05  115017.00  3158177.62
#       July        119046.28   14880.78   217743.22
#       June        117596.14   14699.52   215174.90
#       March       127960.90   18280.13   234154.17
#       May         131759.58   16469.95   241175.30
#       November    116591.28   14573.91   213177.94
#       October     148396.30   18549.54   271728.72
#       September   167732.92   20966.61   307351.00
# 2     April       162529.58   20316.20   297377.76
#       August      159464.84   19933.10   291691.90
#       December    157862.62   19732.83   288402.00
#       February    200984.66   25123.08   367980.24
# ...

# %%
# Out:
#     Region Product  TargetAnnual     Month  Sales
# 0     East   Apple          4678   January    152
# 1     East  Orange          3540   January    485
# 2     East  Banana          4059   January    398
# 3     East   Grape          5572   January    320
# 4     East   Mango          4183   January    156
# ..     ...     ...           ...       ...    ...
# 175  North   Apple          4597  December    437
# 176  North  Orange          5693  December    271
# 177  North  Banana          3795  December    456
# 178  North   Grape          4051  December    280
# 179  North   Mango          4643  December    286
#
# [180 rows x 5 columns]
