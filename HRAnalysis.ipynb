# %%
import pandas as pd
d = pd.read_excel(r"C:\Users\ADMIN\Desktop\Sage's PowerBI BootCamp\HRData.xlsx", sheet_name = "Sheet1" )

# %%
d.head()
# Out:
#               Employee_Name  EmpID  Salary                  Position State  \
# 0       Adinolfi, Wilson  K  10026   62506   Production Technician I    MA
# 1  Ait Sidi, Karthikeyan     10084  104437                   Sr. DBA    MA
# 2         Akinkuolie, Sarah  10196   64955  Production Technician II    MA
# 3              Alagbe,Trina  10088   64991   Production Technician I    MA
# 4          Anderson, Carol   10069   50825   Production Technician I    MA
#
#     Zip        DOB Sex MaritalDesc RaceDesc  ...         Department  \
# 0  1960 1983-10-07  M       Single    White  ...  Production
# 1  2148 1975-05-05  M      Married    White  ...              IT/IS
# 2  1810 1988-09-19   F     Married    White  ...  Production
# 3  1886 1988-09-28   F     Married    White  ...  Production
# 4  2169 1989-08-09   F    Divorced    White  ...  Production
#
#       ManagerName RecruitmentSource PerformanceScore EngagementSurvey  \
# ...

# %%
#checking for nulls
d.isna().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# Salary                        0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# RecruitmentSource             0
# PerformanceScore              0
# EngagementSurvey              0
# EmpSatisfaction               0
# SpecialProjectsCount          0
# LastPerformanceReview_Date    0
# DaysLateLast30                0
# Absences                      0
# dtype: int64

# %%
#unique values in all the columns
for i in d.columns:
    print(i)
    print(d[i].unique())
    print('____________________')
# Out:
# Employee_Name
# ['Adinolfi, Wilson  K' 'Ait Sidi, Karthikeyan   ' 'Akinkuolie, Sarah'
#  'Alagbe,Trina' 'Anderson, Carol ' 'Anderson, Linda  ' 'Andreola, Colby'
#  'Athwal, Sam' 'Bachiochi, Linda' 'Bacong, Alejandro '
#  'Baczenski, Rachael  ' 'Barbara, Thomas' 'Barbossa, Hector'
#  'Barone, Francesco  A' 'Barton, Nader' 'Bates, Norman' 'Beak, Kimberly  '
#  'Beatrice, Courtney ' 'Becker, Renee' 'Becker, Scott' 'Bernstein, Sean'
#  'Biden, Lowan  M' 'Billis, Helen' 'Blount, Dianna' 'Bondwell, Betsy'
#  'Booth, Frank' 'Boutwell, Bonalyn' 'Bozzi, Charles' 'Brill, Donna'
#  'Brown, Mia' 'Buccheri, Joseph  ' 'Bugali, Josephine ' 'Bunbury, Jessica'
#  'Burke, Joelle' 'Burkett, Benjamin ' 'Cady, Max ' 'Candie, Calvin'
#  'Carabbio, Judith' 'Carey, Michael  ' 'Carr, Claudia  N'
#  'Carter, Michelle ' 'Chace, Beatrice ' 'Champaigne, Brian' 'Chan, Lin'
#  'Chang, Donovan  E' 'Chigurh, Anton' 'Chivukula, Enola'
#  'Cierpiszewski, Caroline  ' 'Clayton, Rick' 'Cloninger, Jennifer'
# ...

# %%
d.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'Salary', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'RaceDesc', 'DateofHire', 'DateofTermination',
#        'TermReason', 'EmploymentStatus', 'Department', 'ManagerName',
#        'RecruitmentSource', 'PerformanceScore', 'EngagementSurvey',
#        'EmpSatisfaction', 'SpecialProjectsCount', 'LastPerformanceReview_Date',
#        'DaysLateLast30', 'Absences'],
#       dtype='object')

# %%
#unique value in a column
d.Sex.unique()
# Out:
# array(['M ', 'F'], dtype=object)

# %%
# count of uniquue values in a column
len(d.Sex.unique())
# Out:
# 2

# %%
d.Sex.nunique()
# Out:
# 2

# %%
d.Sex.value_counts()
# Out:
# Sex
# F     176
# M     135
# Name: count, dtype: int64

# %%
# creating a chart 
d.Sex.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
d.Sex.value_counts().plot(kind = 'barh', color = 'black')
# Out:
# <Axes: ylabel='Sex'>

# %%
# renaming a column
d.rename(columns = {'Sex': 'Gender'}, inplace = True)

# %%
d
# Out:
#                 Employee_Name  EmpID  Salary                  Position State  \
# 0         Adinolfi, Wilson  K  10026   62506   Production Technician I    MA
# 1    Ait Sidi, Karthikeyan     10084  104437                   Sr. DBA    MA
# 2           Akinkuolie, Sarah  10196   64955  Production Technician II    MA
# 3                Alagbe,Trina  10088   64991   Production Technician I    MA
# 4            Anderson, Carol   10069   50825   Production Technician I    MA
# ..                        ...    ...     ...                       ...   ...
# 306            Woodson, Jason  10135   65893  Production Technician II    MA
# 307        Ybarra, Catherine   10301   48513   Production Technician I    MA
# 308          Zamora, Jennifer  10010  220450                       CIO    MA
# 309               Zhou, Julia  10043   89292              Data Analyst    MA
# 310             Zima, Colleen  10271   45046   Production Technician I    MA
#
# ...

# %%
# rename a value
d.Gender = d.Gender.str.strip().replace("M", "Male").replace('F', 'Female')

# %%
d
# Out:
#                 Employee_Name  EmpID  Salary                  Position State  \
# 0         Adinolfi, Wilson  K  10026   62506   Production Technician I    MA
# 1    Ait Sidi, Karthikeyan     10084  104437                   Sr. DBA    MA
# 2           Akinkuolie, Sarah  10196   64955  Production Technician II    MA
# 3                Alagbe,Trina  10088   64991   Production Technician I    MA
# 4            Anderson, Carol   10069   50825   Production Technician I    MA
# ..                        ...    ...     ...                       ...   ...
# 306            Woodson, Jason  10135   65893  Production Technician II    MA
# 307        Ybarra, Catherine   10301   48513   Production Technician I    MA
# 308          Zamora, Jennifer  10010  220450                       CIO    MA
# 309               Zhou, Julia  10043   89292              Data Analyst    MA
# 310             Zima, Colleen  10271   45046   Production Technician I    MA
#
# ...

# %%
#Salary by gender
d.groupby('Gender')['Salary'].mean().reset_index()
# Out:
#    Gender        Salary
# 0  Female  67786.727273
# 1    Male  70629.400000

# %%
# analysis by gender. To get total sum, mean and count
d.groupby('Gender')['Salary'].agg(['sum','mean', 'count']).reset_index()
# Out:
#    Gender       sum          mean  count
# 0  Female  11930464  67786.727273    176
# 1    Male   9534969  70629.400000    135

# %%
d.Salary.idxmax()
# Out:
# 150

# %%
d.loc[150,'ManagerName']
# Out:
# 'Board of Directors'

# %%
#get the highest income earner
d[d.Salary==d.Salary.max()]
# Out:
#     Employee_Name  EmpID  Salary         Position State   Zip        DOB  \
# 150   King, Janet  10089  250000  President & CEO    MA  1902 1954-09-21
#
#      Gender MaritalDesc RaceDesc  ...        Department         ManagerName  \
# 150  Female     Married    White  ...  Executive Office  Board of Directors
#
#     RecruitmentSource PerformanceScore EngagementSurvey EmpSatisfaction  \
# 150            Indeed      Fully Meets             4.83               3
#
#     SpecialProjectsCount LastPerformanceReview_Date  DaysLateLast30  Absences
# 150                    0                 2019-01-17               0        10
#
# [1 rows x 24 columns]

# %%
#Get the count of the source from which each race was recruited from
d.groupby(['RecruitmentSource', 'RaceDesc']).size().reset_index()
# Out:
#           RecruitmentSource                          RaceDesc   0
# 0             CareerBuilder                             Asian   2
# 1             CareerBuilder         Black or African American   5
# 2             CareerBuilder                             White  16
# 3        Diversity Job Fair         Black or African American  29
# 4         Employee Referral                             Asian   1
# 5         Employee Referral         Black or African American   5
# 6         Employee Referral                             White  25
# 7             Google Search  American Indian or Alaska Native   1
# 8             Google Search                             Asian   7
# 9             Google Search         Black or African American   4
# 10            Google Search                 Two or more races   2
# 11            Google Search                             White  35
# 12                   Indeed  American Indian or Alaska Native   1
# ...

# %%
d.groupby(['Department', 'RaceDesc']).size().reset_index()
# Out:
#               Department                          RaceDesc    0
# 0          Admin Offices         Black or African American    5
# 1          Admin Offices                             White    4
# 2       Executive Office                             White    1
# 3                  IT/IS                             Asian    6
# 4                  IT/IS         Black or African American   15
# 5                  IT/IS                             White   29
# 6      Production         American Indian or Alaska Native    2
# 7      Production                                    Asian   21
# 8      Production                Black or African American   45
# 9      Production                                 Hispanic    1
# 10     Production                        Two or more races    6
# 11     Production                                    White  134
# 12                 Sales  American Indian or Alaska Native    1
# 13                 Sales                             Asian    1
# ...

# %%
d.sample()
# Out:
#      Employee_Name  EmpID  Salary             Position State   Zip        DOB  \
# 298  Wang, Charlie  10172   84903  Senior BI Developer    MA  1887 1981-08-07
#
#     Gender MaritalDesc RaceDesc  ... Department       ManagerName  \
# 298     M       Single    Asian  ...      IT/IS  Brian Champaigne
#
#     RecruitmentSource PerformanceScore EngagementSurvey EmpSatisfaction  \
# 298            Indeed      Fully Meets             3.42               4
#
#     SpecialProjectsCount LastPerformanceReview_Date  DaysLateLast30  Absences
# 298                    7                 2019-01-04               0        17
#
# [1 rows x 24 columns]

# %%
# What is the distribution of salaries across different departments?
department = d.groupby('Department')['Salary'].agg('mean').reset_index()#.plot(kind='bar')
department
# Out:
#              Department         Salary
# 0         Admin Offices   71791.888889
# 1      Executive Office  250000.000000
# 2                 IT/IS   97064.640000
# 3     Production          59953.545455
# 4                 Sales   69061.258065
# 5  Software Engineering   94989.454545

# %%
#Using matplotlib to plot total sum of salary paid based on each department.
import matplotlib.pyplot as plt
plt.barh(department.Department, department.Salary)
# Out:
# <BarContainer object of 6 artists>

# %%
import seaborn as sns

# %%
sns.barplot(data = department, x ='Department', y='Salary')
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
#Using seaborn to plot total salary paid to each department
sns.barplot(data = department, y ='Department', x='Salary', orient= 'h')
plt.title("Average salary by department")
# Out:
# Text(0.5, 1.0, 'Average salary by department')

# %%
#How does employee satisfaction vary across departments and positions?
d.head(2)
# Out:
#               Employee_Name  EmpID  Salary                 Position State  \
# 0       Adinolfi, Wilson  K  10026   62506  Production Technician I    MA
# 1  Ait Sidi, Karthikeyan     10084  104437                  Sr. DBA    MA
#
#     Zip        DOB Gender MaritalDesc RaceDesc  ...         Department  \
# 0  1960 1983-10-07     M       Single    White  ...  Production
# 1  2148 1975-05-05     M      Married    White  ...              IT/IS
#
#       ManagerName RecruitmentSource PerformanceScore EngagementSurvey  \
# 0  Michael Albert          LinkedIn          Exceeds             4.60
# 1      Simon Roup            Indeed      Fully Meets             4.96
#
#   EmpSatisfaction SpecialProjectsCount LastPerformanceReview_Date  \
# 0               5                    0                 2019-01-17
# 1               3                    6                 2016-02-24
#
#    DaysLateLast30  Absences
# 0               0         1
# 1               0        17
#
# [2 rows x 24 columns]

# %%
#Getting the Employee satisfaction by Department and Position
satisfaction = d.groupby(['Department', 'Position'])['EmpSatisfaction'].mean().reset_index()
satisfaction.head()
# Out:
#          Department                  Position  EmpSatisfaction
# 0     Admin Offices              Accountant I         3.666667
# 1     Admin Offices  Administrative Assistant         3.333333
# 2     Admin Offices   Shared Services Manager         4.000000
# 3     Admin Offices            Sr. Accountant         3.500000
# 4  Executive Office           President & CEO         3.000000

# %%
sns.lineplot(data =satisfaction, y = 'EmpSatisfaction', x='Position' )
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#the performance rate of each recruitment source
d.groupby(['PerformanceScore', 'RecruitmentSource'])['PerformanceScore'].count()
# Out:
# PerformanceScore   RecruitmentSource
# Exceeds            CareerBuilder               2
#                    Diversity Job Fair          6
#                    Employee Referral           5
#                    Google Search               2
#                    Indeed                     12
#                    LinkedIn                    9
#                    Website                     1
# Fully Meets        CareerBuilder              17
#                    Diversity Job Fair         18
#                    Employee Referral          25
#                    Google Search              43
#                    Indeed                     66
#                    LinkedIn                   61
#                    On-line Web application     1
#                    Other                       2
#                    Website                    10
# Needs Improvement  CareerBuilder               4
#                    Diversity Job Fair          4
# ...

# %%
#the performance rate of each recruitment source
pd.DataFrame(d.groupby(['PerformanceScore', 'RecruitmentSource'])['PerformanceScore'].count())
# Out:
#                                            PerformanceScore
# PerformanceScore  RecruitmentSource
# Exceeds           CareerBuilder                           2
#                   Diversity Job Fair                      6
#                   Employee Referral                       5
#                   Google Search                           2
#                   Indeed                                 12
#                   LinkedIn                                9
#                   Website                                 1
# Fully Meets       CareerBuilder                          17
#                   Diversity Job Fair                     18
#                   Employee Referral                      25
#                   Google Search                          43
#                   Indeed                                 66
#                   LinkedIn                               61
#                   On-line Web application                 1
# ...

# %%
d.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'Salary', 'Position', 'State', 'Zip', 'DOB',
#        'Gender', 'MaritalDesc', 'RaceDesc', 'DateofHire', 'DateofTermination',
#        'TermReason', 'EmploymentStatus', 'Department', 'ManagerName',
#        'RecruitmentSource', 'PerformanceScore', 'EngagementSurvey',
#        'EmpSatisfaction', 'SpecialProjectsCount', 'LastPerformanceReview_Date',
#        'DaysLateLast30', 'Absences'],
#       dtype='object')

# %%
# Is there a correlation between salary and employee satisfaction?
d.head(2)
# Out:
#               Employee_Name  EmpID  Salary                 Position State  \
# 0       Adinolfi, Wilson  K  10026   62506  Production Technician I    MA
# 1  Ait Sidi, Karthikeyan     10084  104437                  Sr. DBA    MA
#
#     Zip        DOB Gender MaritalDesc RaceDesc  ...         Department  \
# 0  1960 1983-10-07     M       Single    White  ...  Production
# 1  2148 1975-05-05     M      Married    White  ...              IT/IS
#
#       ManagerName RecruitmentSource PerformanceScore EngagementSurvey  \
# 0  Michael Albert          LinkedIn          Exceeds             4.60
# 1      Simon Roup            Indeed      Fully Meets             4.96
#
#   EmpSatisfaction SpecialProjectsCount LastPerformanceReview_Date  \
# 0               5                    0                 2019-01-17
# 1               3                    6                 2016-02-24
#
#    DaysLateLast30  Absences
# 0               0         1
# 1               0        17
#
# [2 rows x 24 columns]

# %%
#Is there a correclation between employee satisfaction and Absense ?
d.EmpSatisfaction.corr(d.Absences).round(2)
# Out:
# 0.08

# %%
#Calculate the average age of all the employee
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   Salary                      311 non-null    int64
#  3   Position                    311 non-null    object
#  4   State                       311 non-null    object
#  5   Zip                         311 non-null    int64
#  6   DOB                         311 non-null    datetime64[ns]
#  7   Gender                      311 non-null    object
#  8   MaritalDesc                 311 non-null    object
#  9   RaceDesc                    311 non-null    object
#  10  DateofHire                  311 non-null    datetime64[ns]
#  11  DateofTermination           311 non-null    object
#  12  TermReason                  311 non-null    object
# ...

# %%
#Extract the year from the DOB column
d.DOB.dt.year
# Out:
# 0      1983
# 1      1975
# 2      1988
# 3      1988
# 4      1989
#        ...
# 306    1985
# 307    1982
# 308    1979
# 309    1979
# 310    1978
# Name: DOB, Length: 311, dtype: int32

# %%
d['Month'] = d.DOB.dt.month_name()
d['Month']
# Out:
# 0        October
# 1            May
# 2      September
# 3      September
# 4         August
#          ...
# 306     November
# 307        April
# 308       August
# 309     February
# 310       August
# Name: Month, Length: 311, dtype: object

# %%
#subtract 
d['Age'] = 2024 - d.DOB.dt.year
d
# Out:
#                 Employee_Name  EmpID  Salary                  Position State  \
# 0         Adinolfi, Wilson  K  10026   62506   Production Technician I    MA
# 1    Ait Sidi, Karthikeyan     10084  104437                   Sr. DBA    MA
# 2           Akinkuolie, Sarah  10196   64955  Production Technician II    MA
# 3                Alagbe,Trina  10088   64991   Production Technician I    MA
# 4            Anderson, Carol   10069   50825   Production Technician I    MA
# ..                        ...    ...     ...                       ...   ...
# 306            Woodson, Jason  10135   65893  Production Technician II    MA
# 307        Ybarra, Catherine   10301   48513   Production Technician I    MA
# 308          Zamora, Jennifer  10010  220450                       CIO    MA
# 309               Zhou, Julia  10043   89292              Data Analyst    MA
# 310             Zima, Colleen  10271   45046   Production Technician I    MA
#
# ...

# %%
#Mean age of employee
d.Age.mean()
# Out:
# 45.40836012861736

# %%
#Oldest Worker ?
d.Age.max()
# Out:
# 73

# %%
#Youngest worker
d.Age.min()
# Out:
# 32

# %%
#Name of the oldest
d.Age.argmin() # this gives us the row number where the least value in Age occured
# Out:
# 110

# %%
# information of the youngest
d.iloc[[110],:]
# Out:
#        Employee_Name  EmpID  Salary                 Position State   Zip  \
# 110  Gold, Shenice    10243   53018  Production Technician I    MA  2451
#
#            DOB Gender MaritalDesc RaceDesc  ...    ManagerName  \
# 110 1992-06-18      F      Single    White  ...  Ketsia Liebig
#
#     RecruitmentSource PerformanceScore EngagementSurvey EmpSatisfaction  \
# 110            Indeed      Fully Meets              4.3               5
#
#     SpecialProjectsCount LastPerformanceReview_Date DaysLateLast30  Absences  \
# 110                    0                 2019-02-18              0         7
#
#      Age
# 110   32
#
# [1 rows x 25 columns]

# %%
#Name of the Oldest
d.Age.argmax()
# Out:
# 41

# %%
#Information about the oldest
d.iloc[[41],:]
# Out:
#        Employee_Name  EmpID  Salary                 Position State   Zip  \
# 41  Chace, Beatrice   10067   61656  Production Technician I    MA  2763
#
#           DOB Gender MaritalDesc RaceDesc  ...     ManagerName  \
# 41 1951-02-01      F      Single    White  ...  Michael Albert
#
#    RecruitmentSource PerformanceScore EngagementSurvey EmpSatisfaction  \
# 41     Google Search      Fully Meets              5.0               4
#
#    SpecialProjectsCount LastPerformanceReview_Date DaysLateLast30  Absences  \
# 41                    0                 2019-02-12              0        11
#
#     Age
# 41   73
#
# [1 rows x 25 columns]

# %%
d[d.Salary==d.Salary.max()]
# Out:
#     Employee_Name  EmpID  Salary         Position State   Zip        DOB  \
# 150   King, Janet  10089  250000  President & CEO    MA  1902 1954-09-21
#
#     Gender MaritalDesc RaceDesc  ... RecruitmentSource PerformanceScore  \
# 150      F     Married    White  ...            Indeed      Fully Meets
#
#     EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 150             4.83               3                    0
#
#     LastPerformanceReview_Date DaysLateLast30 Absences  Age      Month
# 150                 2019-01-17              0       10   70  September
#
# [1 rows x 26 columns]

# %%
# top ten salary earners
d.sort_values(by = 'Salary', ascending = False).head(10)
# Out:
#         Employee_Name  EmpID  Salary                Position State   Zip  \
# 150       King, Janet  10089  250000         President & CEO    MA  1902
# 308  Zamora, Jennifer  10010  220450                     CIO    MA  2067
# 131   Houlihan, Debra  10272  180000       Director of Sales    RI  2908
# 96        Foss, Jason  10015  178000             IT Director    MA  1460
# 55     Corleone, Vito  10019  170500  Director of Operations    MA  2030
# 190     Monroe, Peter  10288  157000      IT Manager - Infra    MA  2134
# 240      Roper, Katie  10086  150290          Data Architect    MA  2056
# 244     Ruiz, Ricardo  10222  148999         IT Manager - DB    MA  1915
# 243        Roup,Simon  10198  140920         IT Manager - DB    MA  2481
# 76      Dougall, Eric  10028  138888    IT Manager - Support    MA  1886
#
#            DOB Gender MaritalDesc                   RaceDesc  ...  \
# 150 1954-09-21      F     Married                      White  ...
# ...

# %%
h = d[['Employee_Name', 'Salary']].sort_values(by = 'Salary', ascending = False).head(10)

# %%
h
# Out:
#         Employee_Name  Salary
# 150       King, Janet  250000
# 308  Zamora, Jennifer  220450
# 131   Houlihan, Debra  180000
# 96        Foss, Jason  178000
# 55     Corleone, Vito  170500
# 190     Monroe, Peter  157000
# 240      Roper, Katie  150290
# 244     Ruiz, Ricardo  148999
# 243        Roup,Simon  140920
# 76      Dougall, Eric  138888

# %%
plt.barh(h.Employee_Name, h.Salary, color = 'Red')
plt.title("Top 10 salary earners")
# Out:
# Text(0.5, 1.0, 'Top 10 salary earners')
